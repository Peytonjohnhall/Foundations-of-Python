# %%
student_names = ["Alice", "Bob", "Carlos", "Diana", "Ethan",
                  "Fiona", "George", "Hannah"]
student_grades = [88, 72, 95, 61, 84, 77, 90, 68]

# %%
student_names[::-1]
# Out:
# ['Hannah', 'George', 'Fiona', 'Ethan', 'Diana', 'Carlos', 'Bob', 'Alice']

# %%
student_names[0:8:2]
# Out:
# ['Alice', 'Carlos', 'Ethan', 'George']
